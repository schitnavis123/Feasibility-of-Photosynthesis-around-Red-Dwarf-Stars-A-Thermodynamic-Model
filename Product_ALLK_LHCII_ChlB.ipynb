# %% [markdown]
# ## Product_ALLK_LHCII_ChlB

# %%
import matplotlib.pyplot as plt #import plt function from matplotlib library
import numpy as np 
from numpy import trapz
from matplotlib.ticker import (MultipleLocator, #major/minor ticks
           FormatStrFormatter, AutoMinorLocator)
import math
import pandas as pd 

res = 1

s_2800K_1 = []
s_2800K_2 = [] 
s_3300K_1 = []
s_3300K_2 = [] 
s_3700K_1 = []
s_3700K_2 = [] 
s_4400K_1 = []
s_4400K_2 = [] 
s_5800K_1 = []
s_5800K_2 = [] 


counter = 1

with open('fp_2800K.txt') as fp2800K, open('LHCII_chlb_interp.txt') as LHCII_chlb_interp, open('Product_2800_LHCII_chlb.txt', mode = 'w') as fout2800K:
    for line1, line2 in zip(fp2800K, LHCII_chlb_interp): #zip() aggregates your separate files in the brackets
        line1, line2 = line1.rstrip(), line2.rstrip() 
        col1, col2 = line1.split('\t'), line2.split('\t') #creates column 1 (wavelength, fp) and column 2 (wavelength, LHCII_interp)
        
        wavelength_2800K = float(col1[0]) #1st element in column 1 (could also do col2[0]) 
        product_2800K = float(col1[1])*float(col2[1]) #2nd element in column 1 x 2nd element in column 2
        
        counter = counter + 1 
                                        
        if counter%res == 0: 
            s_2800K_1.append(wavelength_2800K) 
            s_2800K_2.append(product_2800K) 
            

with open('fp_3300K.txt') as fp3300K, open('LHCII_chlb_interp.txt') as LHCII_chlb_interp, open('Product_3300_LHCII_chlb.txt', mode = 'w') as fout3300K:
    for line1, line2 in zip(fp3300K, LHCII_chlb_interp): #zip() aggregates your separate files in the brackets
        line1, line2 = line1.rstrip(), line2.rstrip() 
        col1, col2 = line1.split('\t'), line2.split('\t') #creates column 1 (wavelength, fp) and column 2 (wavelength, LHCII_interp)
        
        wavelength_3300K = float(col1[0]) #1st element in column 1 (could also do col2[0]) 
        product_3300K = float(col1[1])*float(col2[1]) #2nd element in column 1 x 2nd element in column 2
        
        counter = counter + 1 
                                        
        if counter%res == 0: 
            s_3300K_1.append(wavelength_3300K) 
            s_3300K_2.append(product_3300K) 
          
            
with open('fp_3700K.txt') as fp3700K, open('LHCII_chlb_interp.txt') as LHCII_chlb_interp, open('Product_3700_LHCII_chlb.txt', mode = 'w') as fout3700K:
    for line1, line2 in zip(fp3700K, LHCII_chlb_interp): #zip() aggregates your separate files in the brackets
        line1, line2 = line1.rstrip(), line2.rstrip() 
        col1, col2 = line1.split('\t'), line2.split('\t') #creates column 1 (wavelength, fp) and column 2 (wavelength, LHCII_interp)
        
        wavelength_3700K = float(col1[0]) #1st element in column 1 (could also do col2[0]) 
        product_3700K = float(col1[1])*float(col2[1]) #2nd element in column 1 x 2nd element in column 2
        
        counter = counter + 1 
                                        
        if counter%res == 0: 
            s_3700K_1.append(wavelength_3700K) 
            s_3700K_2.append(product_3700K) 
        
            
with open('fp_4400K.txt') as fp4400K, open('LHCII_chlb_interp.txt') as LHCII_chlb_interp, open('Product_4400_LHCII_chlb.txt', mode = 'w') as fout4400K:
    for line1, line2 in zip(fp4400K, LHCII_chlb_interp): #zip() aggregates your separate files in the brackets
        line1, line2 = line1.rstrip(), line2.rstrip() 
        col1, col2 = line1.split('\t'), line2.split('\t') #creates column 1 (wavelength, fp) and column 2 (wavelength, LHCII_interp)
        
        wavelength_4400K = float(col1[0]) #1st element in column 1 (could also do col2[0]) 
        product_4400K = float(col1[1])*float(col2[1]) #2nd element in column 1 x 2nd element in column 2
        
        counter = counter + 1 
                                        
        if counter%res == 0: 
            s_4400K_1.append(wavelength_4400K) 
            s_4400K_2.append(product_4400K) 
            
with open('fp_5800K.txt') as fp5800K, open('LHCII_chlb_interp.txt') as LHCII_chlb_interp, open('Product_5800_LHCII_chlb.txt', mode = 'w') as fout5800K:
    for line1, line2 in zip(fp5800K, LHCII_chlb_interp): #zip() aggregates your separate files in the brackets
        line1, line2 = line1.rstrip(), line2.rstrip() 
        col1, col2 = line1.split('\t'), line2.split('\t') #creates column 1 (wavelength, fp) and column 2 (wavelength, LHCII_interp)
        
        wavelength_5800K = float(col1[0]) #1st element in column 1 (could also do col2[0]) 
        product_5800K = float(col1[1])*float(col2[1]) #2nd element in column 1 x 2nd element in column 2
        
        counter = counter + 1 
                                        
        if counter%res == 0: 
            s_5800K_1.append(wavelength_5800K) 
            s_5800K_2.append(product_5800K) 


#fout.close() 

#plotting
fig, ax = plt.subplots(figsize=(15, 10))
ax.set_title('Absolute Power in for ChlB LHCII antenna', fontsize=20) 
ax.set_ylabel('Amplitude ($au$)', fontsize=14)
ax.set_xlabel('Wavelength ($nm$)', fontsize=14) 

ax.plot(s_5800K_1,s_5800K_2,linestyle='-',color='b',label='T=5800K; Pin=0.867')
ax.plot(s_4400K_1,s_4400K_2,linestyle='-',color='c',label='T=4400K; Pin=0.719')
ax.plot(s_3700K_1,s_3700K_2,linestyle='-',color='g',label='T=3700K; Pin=0.448')
ax.plot(s_3300K_1,s_3300K_2,linestyle='-',color='tab:orange',label='T=3300K; Pin=0.277')
ax.plot(s_2800K_1,s_2800K_2,linestyle='-',color='r',label='T=2800K; Pin=0.074')

ax.set_ylim(0, 0.08)

plt.legend() 
plt.savefig('Product_ALLK_LHCII_ChlB.pdf') 
plt.show() 

## Integral

#print('Pin for LHCII antenna for 2800K star:', np.trapz(s_2800K_2, s_2800K_1))
#print('Pin for LHCII antenna for 3300K star:', np.trapz(s_3300K_2, s_3300K_1))
#print('Pin for LHCII antenna for 3700K star:', np.trapz(s_3700K_2, s_3700K_1))
#print('Pin for LHCII antenna for 4400K star:', np.trapz(s_4400K_2, s_4400K_1))
#print('Pin for LHCII antenna for 5800K star:', np.trapz(s_5800K_2, s_5800K_1))

integral_2800K = 0.0 
integral_3300K = 0.0 
integral_3700K = 0.0 
integral_4400K = 0.0 
integral_5800K = 0.0 

for i in range(0, len(s_2800K_2)-1): 
    binwidth = s_2800K_1[i+1] - s_2800K_1[i] 
    integral_2800K = integral_2800K + s_2800K_2[i]*binwidth
for i in range(0, len(s_3300K_2)-1): 
    binwidth = s_3300K_1[i+1] - s_3300K_1[i] 
    integral_3300K = integral_3300K + s_3300K_2[i]*binwidth   
for i in range(0, len(s_3700K_2)-1): 
    binwidth = s_3700K_1[i+1] - s_3700K_1[i] 
    integral_3700K = integral_3700K + s_3700K_2[i]*binwidth 
for i in range(0, len(s_4400K_2)-1): 
    binwidth = s_4400K_1[i+1] - s_4400K_1[i] 
    integral_4400K = integral_4400K + s_4400K_2[i]*binwidth 
for i in range(0, len(s_5800K_2)-1): 
    binwidth = s_5800K_1[i+1] - s_5800K_1[i] 
    integral_5800K = integral_5800K + s_5800K_2[i]*binwidth
    
print('Pin for LHCII antenna for 2800K star:', integral_2800K)
print('Pin for LHCII antenna for 3300K star:', integral_3300K)
print('Pin for LHCII antenna for 3700K star:', integral_3700K)
print('Pin for LHCII antenna for 4400K star:', integral_4400K)
print('Pin for LHCII antenna for 5800K star:', integral_5800K)
# Out:
# Pin for LHCII antenna for 2800K star: 0.07372585565601766
# Pin for LHCII antenna for 3300K star: 0.2771389991933741
# Pin for LHCII antenna for 3700K star: 0.4480692782472346
# Pin for LHCII antenna for 4400K star: 0.7193162700028457
# Pin for LHCII antenna for 5800K star: 0.8666511982939029
